# %% [markdown]
# # セグメンテーション1

# %% [markdown]
# 【問題1】学習・推定

# %%
# 自分のマイドライブにマウントする
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# %cd /content/drive/MyDrive/tgs-salt-identification-challenge/competition_data/test/images
# Out:
# /content/drive/MyDrive/tgs-salt-identification-challenge/competition_data/test/images

# %%
import os
path = '/content/drive/MyDrive/tgs-salt-identification-challenge/competition_data/test/images'
flist = os.listdir(path)

# %%
flist_ignore = [name for name in os.listdir(path) if not name.startswith('.')]
len(flist_ignore)
# Out:
# 18002

# %%
i=0
for file in flist_ignore:
  os.rename(file, str(i)+'.png')
  i+=1

flist_ignore = [name for name in os.listdir(path) if not name.startswith('.')]
len(flist_ignore)
# Out:
# 18002

# %%
flist_ignore
# Out:
# ['0.png',
#  '1.png',
#  '2.png',
#  '3.png',
#  '4.png',
#  '5.png',
#  '6.png',
#  '7.png',
#  '8.png',
#  '9.png',
#  '10.png',
#  '11.png',
#  '12.png',
#  '13.png',
#  '14.png',
#  '15.png',
#  '16.png',
#  '17.png',
#  '18.png',
#  '19.png',
#  '20.png',
#  '21.png',
#  '22.png',
#  '23.png',
#  '24.png',
#  '25.png',
#  '26.png',
#  '27.png',
#  '28.png',
#  '29.png',
#  '30.png',
#  '31.png',
#  '32.png',
#  '33.png',
#  '34.png',
#  '35.png',
#  '36.png',
#  '37.png',
#  '38.png',
#  '39.png',
#  '40.png',
#  '41.png',
#  '42.png',
#  '43.png',
#  '44.png',
#  '45.png',
#  '46.png',
#  '47.png',
#  '48.png',
#  '49.png',
#  '50.png',
#  '51.png',
#  '52.png',
#  '53.png',
#  '54.png',
#  '55.png',
#  '56.png',
#  '57.png',
#  '58.png',
#  '59.png',
#  '60.png',
#  '61.png',
#  '62.png',
#  '63.png',
#  '64.png',
#  '65.png',
#  '66.png',
#  '67.png',
#  '68.png',
#  '69.png',
#  '70.png',
#  '71.png',
#  '72.png',
#  '73.png',
#  '74.png',
#  '75.png',
#  '76.png',
# ...

# %%
# !git clone https://github.com/zhixuhao/unet.git
# Out:
# Cloning into 'unet'...
# remote: Enumerating objects: 394, done.
# remote: Total 394 (delta 0), reused 0 (delta 0), pack-reused 394
# Receiving objects: 100% (394/394), 44.92 MiB | 18.95 MiB/s, done.
# Resolving deltas: 100% (80/80), done.
# Checking out files: 100% (253/253), done.

# %%
# %cd /content/drive/MyDrive/unet/
# Out:
# /content/drive/MyDrive/unet

# %%
# !ls -a
# Out:
# data		   data.py  img      main.py   README.md
# dataPrepare.ipynb  .git     LICENSE  model.py  trainUnet.ipynb

# %%
# !pip install tensorflow==1.15.0 
# !pip install keras==2.2.4
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/92/2b/e3af15221da9ff323521565fa3324b0d7c7c5b1d7a8ca66984c8d59cb0ce/tensorflow-1.15.0-cp37-cp37m-manylinux2010_x86_64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/de/62/2ee9cd74c9fa2fa450877847ba560b260f5d0fb70ee0595203082dafcc9d/tensorflow_estimator-1.15.1-py2.py3-none-any.whl
# ...
# Processing /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd/gast-0.2.2-cp37-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/1e/e9/d3d747a97f7188f48aa5eda486907f3b345cd409f0a0850468ba867db246/tensorboard-1.15.0-py3-none-any.whl
# ...
# ERROR: tensorflow-probability 0.12.1 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# ...
#   Found existing installation: tensorflow-estimator 2.2.0
#     Uninstalling tensorflow-estimator-2.2.0:
#       Successfully uninstalled tensorflow-estimator-2.2.0
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
# ...

# %%
# !python main.py
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:4185: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# ...

# %% [markdown]
# 【問題2】コードリーディング

# %% [markdown]
# UNetのアーキテクチャ：<br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# このアーキテクチャを実装している場所：<br>
# ->[model.pyファイル](https://github.com/zhixuhao/unet/blob/master/model.py)<br>
# ->[Upsample2Dについて](https://www.tensorflow.org/api_docs/python/tf/keras/layers/UpSampling2D?hl=ja)
